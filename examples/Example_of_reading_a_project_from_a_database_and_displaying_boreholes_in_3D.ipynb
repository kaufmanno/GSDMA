# %% [markdown]
# # Example of using the project class

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
from striplog import Component, Decor, Legend, Interval, Position
from core.omf import Borehole3D, striplog_legend_to_omf_legend 
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from core.core import Project
from utils.orm import get_interval_list

# %% [markdown]
# ### Define the components and the way to display them

# %%
components = [Component({'lithology': 'siltstone', 'colour': 'grey'}),
              Component({'lithology': 'anhydrite'}),
              Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'}),
              Component({'lithology': 'dolomite'}),
              Component({'lithology': 'siltstone', 'colour': 'red'}),
              Component({'lithology': 'limestone'})]
list_of_decors=[]
hatches = ['=', 'x', '.', 's', '=', 'b']
colours = ['#888888', '#882222', '#AAAAAA', '#CC22CC', '#CC2222', '#2222CC']
for i in range(len(components)):
    d = {'color': colours[i],
         'hatch': hatches[i],
         'component': components[i],
         'width': 3}
    decor = Decor(d)
    list_of_decors.append(decor)
legend = Legend(list_of_decors)

# %% [markdown]
# ## Get the interval list

# %%
engine = create_engine('sqlite:///tmp/test_orm_db.db', echo=True)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ### Create the Borehole 3D object using the legend

# %%
p = Project(session, legend=legend)
# Out:
# 2020-12-18 19:11:08,694 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-12-18 19:11:08,695 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-18 19:11:08,701 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-12-18 19:11:08,702 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-18 19:11:08,703 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-12-18 19:11:08,704 INFO sqlalchemy.engine.base.Engine SELECT "Boreholes".id AS "Boreholes_id"
# FROM "Boreholes"
# 2020-12-18 19:11:08,705 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-18 19:11:08,708 INFO sqlalchemy.engine.base.Engine SELECT "Intervals".id AS "Intervals_id", "Intervals".borehole AS "Intervals_borehole", "Intervals".interval_number AS "Intervals_interval_number", "Intervals".description AS "Intervals_description", "Intervals".top_id AS "Intervals_top_id", "Intervals".base_id AS "Intervals_base_id"
# FROM "Intervals"
# WHERE ? = "Intervals".borehole
# 2020-12-18 19:11:08,709 INFO sqlalchemy.engine.base.Engine ('F01',)
# 2020-12-18 19:11:08,711 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,712 INFO sqlalchemy.engine.base.Engine (0,)
# 2020-12-18 19:11:08,714 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,715 INFO sqlalchemy.engine.base.Engine (1,)
# 2020-12-18 19:11:08,721 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,722 INFO sqlalchemy.engine.base.Engine (2,)
# 2020-12-18 19:11:08,723 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,723 INFO sqlalchemy.engine.base.Engine (3,)
# 2020-12-18 19:11:08,724 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,725 INFO sqlalchemy.engine.base.Engine (4,)
# 2020-12-18 19:11:08,726 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,727 INFO sqlalchemy.engine.base.Engine (5,)
# 2020-12-18 19:11:08,728 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,728 INFO sqlalchemy.engine.base.Engine (6,)
# 2020-12-18 19:11:08,730 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,730 INFO sqlalchemy.engine.base.Engine (7,)
# 2020-12-18 19:11:08,732 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,733 INFO sqlalchemy.engine.base.Engine (8,)
# 2020-12-18 19:11:08,736 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,737 INFO sqlalchemy.engine.base.Engine (9,)
# 2020-12-18 19:11:08,739 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,739 INFO sqlalchemy.engine.base.Engine (10,)
# 2020-12-18 19:11:08,740 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,741 INFO sqlalchemy.engine.base.Engine (11,)
# 2020-12-18 19:11:08,743 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,744 INFO sqlalchemy.engine.base.Engine (12,)
# 2020-12-18 19:11:08,745 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,747 INFO sqlalchemy.engine.base.Engine (13,)
# 2020-12-18 19:11:08,752 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,755 INFO sqlalchemy.engine.base.Engine (14,)
# 2020-12-18 19:11:08,757 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,758 INFO sqlalchemy.engine.base.Engine (15,)
# 2020-12-18 19:11:08,760 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,762 INFO sqlalchemy.engine.base.Engine (16,)
# 2020-12-18 19:11:08,766 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,767 INFO sqlalchemy.engine.base.Engine (17,)
# 2020-12-18 19:11:08,769 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,772 INFO sqlalchemy.engine.base.Engine (18,)
# 2020-12-18 19:11:08,775 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,775 INFO sqlalchemy.engine.base.Engine (19,)
# 2020-12-18 19:11:08,777 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,778 INFO sqlalchemy.engine.base.Engine (20,)
# 2020-12-18 19:11:08,781 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,782 INFO sqlalchemy.engine.base.Engine (21,)
# 2020-12-18 19:11:08,786 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,789 INFO sqlalchemy.engine.base.Engine (22,)
# 2020-12-18 19:11:08,794 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,805 INFO sqlalchemy.engine.base.Engine (23,)
# 2020-12-18 19:11:08,807 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,808 INFO sqlalchemy.engine.base.Engine (24,)
# 2020-12-18 19:11:08,810 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,811 INFO sqlalchemy.engine.base.Engine (25,)
# 2020-12-18 19:11:08,814 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,815 INFO sqlalchemy.engine.base.Engine (26,)
# 2020-12-18 19:11:08,820 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,821 INFO sqlalchemy.engine.base.Engine (27,)
# 2020-12-18 19:11:08,823 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,825 INFO sqlalchemy.engine.base.Engine (28,)
# 2020-12-18 19:11:08,828 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,833 INFO sqlalchemy.engine.base.Engine (29,)
# 2020-12-18 19:11:08,836 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,837 INFO sqlalchemy.engine.base.Engine (30,)
# 2020-12-18 19:11:08,839 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,839 INFO sqlalchemy.engine.base.Engine (31,)
# 2020-12-18 19:11:08,841 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,842 INFO sqlalchemy.engine.base.Engine (32,)
# 2020-12-18 19:11:08,843 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,844 INFO sqlalchemy.engine.base.Engine (33,)
# 2020-12-18 19:11:08,846 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,847 INFO sqlalchemy.engine.base.Engine (34,)
# 2020-12-18 19:11:08,849 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,849 INFO sqlalchemy.engine.base.Engine (35,)
# 2020-12-18 19:11:08,853 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,854 INFO sqlalchemy.engine.base.Engine (36,)
# 2020-12-18 19:11:08,855 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,856 INFO sqlalchemy.engine.base.Engine (37,)
# 2020-12-18 19:11:08,858 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,859 INFO sqlalchemy.engine.base.Engine (38,)
# 2020-12-18 19:11:08,861 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,861 INFO sqlalchemy.engine.base.Engine (39,)
# 2020-12-18 19:11:08,865 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,867 INFO sqlalchemy.engine.base.Engine (40,)
# 2020-12-18 19:11:08,869 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,869 INFO sqlalchemy.engine.base.Engine (41,)
# 2020-12-18 19:11:08,871 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,872 INFO sqlalchemy.engine.base.Engine (42,)
# 2020-12-18 19:11:08,876 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,877 INFO sqlalchemy.engine.base.Engine (43,)
# 2020-12-18 19:11:08,878 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,880 INFO sqlalchemy.engine.base.Engine (44,)
# 2020-12-18 19:11:08,884 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,886 INFO sqlalchemy.engine.base.Engine (45,)
# 2020-12-18 19:11:08,888 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,889 INFO sqlalchemy.engine.base.Engine (46,)
# 2020-12-18 19:11:08,890 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,891 INFO sqlalchemy.engine.base.Engine (47,)
# 2020-12-18 19:11:08,892 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,893 INFO sqlalchemy.engine.base.Engine (48,)
# 2020-12-18 19:11:08,894 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,895 INFO sqlalchemy.engine.base.Engine (49,)
# [Interval({'top': Position({'middle': 14.3, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 51.24117647058824, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 51.24117647058824, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 54.81764705882354, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 54.81764705882354, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 56.55882352941177, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 56.55882352941177, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 58.86470588235295, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 60.464705882352945, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 61.45294117647059, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 61.45294117647059, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 62.77058823529413, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 62.77058823529413, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 63.94705882352942, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Siltstone, red', 'data': {}, 'components': [Component({'lithology': 'siltstone', 'colour': 'red'})]}), Interval({'top': Position({'middle': 63.94705882352942, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 64.37058823529412, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 64.37058823529412, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 65.0764705882353, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Siltstone, grey', 'data': {}, 'components': [Component({'lithology': 'siltstone', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 65.0764705882353, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 66.77058823529413, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 66.77058823529413, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 71.10000000000001, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 71.10000000000001, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 71.80588235294118, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 71.80588235294118, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 81.78235294117647, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 81.78235294117647, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 85.78235294117647, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Siltstone, grey', 'data': {}, 'components':  ...
# Borehole geometry created successfully !
# 2020-12-18 19:11:08,936 INFO sqlalchemy.engine.base.Engine SELECT "Intervals".id AS "Intervals_id", "Intervals".borehole AS "Intervals_borehole", "Intervals".interval_number AS "Intervals_interval_number", "Intervals".description AS "Intervals_description", "Intervals".top_id AS "Intervals_top_id", "Intervals".base_id AS "Intervals_base_id"
# FROM "Intervals"
# WHERE ? = "Intervals".borehole
# 2020-12-18 19:11:08,938 INFO sqlalchemy.engine.base.Engine ('F02',)
# 2020-12-18 19:11:08,941 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,943 INFO sqlalchemy.engine.base.Engine (50,)
# 2020-12-18 19:11:08,945 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,948 INFO sqlalchemy.engine.base.Engine (51,)
# 2020-12-18 19:11:08,956 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,957 INFO sqlalchemy.engine.base.Engine (52,)
# 2020-12-18 19:11:08,959 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,960 INFO sqlalchemy.engine.base.Engine (53,)
# 2020-12-18 19:11:08,961 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,966 INFO sqlalchemy.engine.base.Engine (54,)
# 2020-12-18 19:11:08,969 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,970 INFO sqlalchemy.engine.base.Engine (55,)
# 2020-12-18 19:11:08,972 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,972 INFO sqlalchemy.engine.base.Engine (56,)
# 2020-12-18 19:11:08,974 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,975 INFO sqlalchemy.engine.base.Engine (57,)
# 2020-12-18 19:11:08,976 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,977 INFO sqlalchemy.engine.base.Engine (58,)
# 2020-12-18 19:11:08,979 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,980 INFO sqlalchemy.engine.base.Engine (59,)
# 2020-12-18 19:11:08,983 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,985 INFO sqlalchemy.engine.base.Engine (60,)
# 2020-12-18 19:11:08,986 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,986 INFO sqlalchemy.engine.base.Engine (61,)
# 2020-12-18 19:11:08,988 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,989 INFO sqlalchemy.engine.base.Engine (62,)
# 2020-12-18 19:11:08,990 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,991 INFO sqlalchemy.engine.base.Engine (63,)
# 2020-12-18 19:11:08,993 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,994 INFO sqlalchemy.engine.base.Engine (64,)
# 2020-12-18 19:11:08,997 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:08,998 INFO sqlalchemy.engine.base.Engine (65,)
# 2020-12-18 19:11:09,002 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,005 INFO sqlalchemy.engine.base.Engine (66,)
# 2020-12-18 19:11:09,006 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,008 INFO sqlalchemy.engine.base.Engine (67,)
# 2020-12-18 19:11:09,010 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,011 INFO sqlalchemy.engine.base.Engine (68,)
# 2020-12-18 19:11:09,014 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,015 INFO sqlalchemy.engine.base.Engine (69,)
# 2020-12-18 19:11:09,022 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,023 INFO sqlalchemy.engine.base.Engine (70,)
# 2020-12-18 19:11:09,025 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,026 INFO sqlalchemy.engine.base.Engine (71,)
# 2020-12-18 19:11:09,028 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,030 INFO sqlalchemy.engine.base.Engine (72,)
# 2020-12-18 19:11:09,035 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,036 INFO sqlalchemy.engine.base.Engine (73,)
# 2020-12-18 19:11:09,038 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,038 INFO sqlalchemy.engine.base.Engine (74,)
# 2020-12-18 19:11:09,040 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,040 INFO sqlalchemy.engine.base.Engine (75,)
# 2020-12-18 19:11:09,042 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,043 INFO sqlalchemy.engine.base.Engine (76,)
# 2020-12-18 19:11:09,046 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,047 INFO sqlalchemy.engine.base.Engine (77,)
# 2020-12-18 19:11:09,052 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,053 INFO sqlalchemy.engine.base.Engine (78,)
# 2020-12-18 19:11:09,055 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,056 INFO sqlalchemy.engine.base.Engine (79,)
# 2020-12-18 19:11:09,058 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,059 INFO sqlalchemy.engine.base.Engine (80,)
# 2020-12-18 19:11:09,061 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,061 INFO sqlalchemy.engine.base.Engine (81,)
# 2020-12-18 19:11:09,064 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,065 INFO sqlalchemy.engine.base.Engine (82,)
# 2020-12-18 19:11:09,068 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,071 INFO sqlalchemy.engine.base.Engine (83,)
# 2020-12-18 19:11:09,073 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,073 INFO sqlalchemy.engine.base.Engine (84,)
# 2020-12-18 19:11:09,075 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,075 INFO sqlalchemy.engine.base.Engine (85,)
# 2020-12-18 19:11:09,077 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,077 INFO sqlalchemy.engine.base.Engine (86,)
# 2020-12-18 19:11:09,079 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,080 INFO sqlalchemy.engine.base.Engine (87,)
# 2020-12-18 19:11:09,083 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,087 INFO sqlalchemy.engine.base.Engine (88,)
# 2020-12-18 19:11:09,089 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,089 INFO sqlalchemy.engine.base.Engine (89,)
# 2020-12-18 19:11:09,091 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,091 INFO sqlalchemy.engine.base.Engine (90,)
# 2020-12-18 19:11:09,093 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,094 INFO sqlalchemy.engine.base.Engine (91,)
# 2020-12-18 19:11:09,095 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,098 INFO sqlalchemy.engine.base.Engine (92,)
# 2020-12-18 19:11:09,102 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,104 INFO sqlalchemy.engine.base.Engine (93,)
# 2020-12-18 19:11:09,107 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,108 INFO sqlalchemy.engine.base.Engine (94,)
# 2020-12-18 19:11:09,110 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,110 INFO sqlalchemy.engine.base.Engine (95,)
# 2020-12-18 19:11:09,112 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,114 INFO sqlalchemy.engine.base.Engine (96,)
# 2020-12-18 19:11:09,115 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,116 INFO sqlalchemy.engine.base.Engine (97,)
# 2020-12-18 19:11:09,119 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,120 INFO sqlalchemy.engine.base.Engine (98,)
# 2020-12-18 19:11:09,121 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-18 19:11:09,122 INFO sqlalchemy.engine.base.Engine (99,)
# [Interval({'top': Position({'middle': 14.3, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 51.24117647058824, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 51.24117647058824, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 54.81764705882354, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 54.81764705882354, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 56.55882352941177, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 56.55882352941177, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 58.86470588235295, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 60.464705882352945, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 61.45294117647059, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 61.45294117647059, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 62.77058823529413, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 62.77058823529413, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 63.94705882352942, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Siltstone, red', 'data': {}, 'components': [Component({'lithology': 'siltstone', 'colour': 'red'})]}), Interval({'top': Position({'middle': 63.94705882352942, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 64.37058823529412, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 64.37058823529412, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 65.0764705882353, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Siltstone, grey', 'data': {}, 'components': [Component({'lithology': 'siltstone', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 65.0764705882353, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 66.77058823529413, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 66.77058823529413, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 71.10000000000001, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 71.10000000000001, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 71.80588235294118, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 71.80588235294118, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 81.78235294117647, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 81.78235294117647, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 85.78235294117647, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'des ...
# Borehole geometry created successfully !

# %%
p.plot3d(x3d=True)
# Out:
# <html>
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <title>X3D scene</title>
#  <p><script type='text/javascript' src='http://www.x3dom.org/download/x3dom.js'> </script>
# <link rel='stylesheet' type='text/css' href='http://www.x3dom.org/download/x3dom.css'/>
# </head>
# <body>
# <p>
#  For interaction, click in the view and press "a" to see the whole scene. For more info on interaction, please read  <a href="https://doc.x3dom.org/tutorials/animationInteraction/navigation/index.html">the docs</a>
# </p>
# <x3d width='968px' height='600px'>
#  <scene>
# <viewpoint position="-1.94639 1.79771 -2.89271" orientation="0.03886 0.99185 0.12133 3.75685"></viewpoint>
#  <Inline nameSpaceName="Borehole" mapDEFToID="true" url="project_new_project.x3d" />
# </scene>
# </x3d>
# </body>
# </html>
