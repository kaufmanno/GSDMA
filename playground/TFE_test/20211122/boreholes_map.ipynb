# %%
# %matplotlib inline

import pandas as pd
import geopandas as gpd
from definitions import ROOT_DIR

# %%
df = pd.read_csv(ROOT_DIR + '/CF_data/Result_traitem/fusion_finale/Boreholes.csv')

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.X, df.Y))

# %%
gdf.plot(figsize=(16,8), markersize=0.5)
# Out:
# <AxesSubplot:>

# %%
gdf.to_file('bh.gpkg')
