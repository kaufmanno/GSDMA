# %%
import pyvista as pv
import pandas as pd
import numpy as np

# %%
cyl = pv.Cylinder(
    center=(0.0, 0.0, 0.0),
    direction=(0.0, 0.0, 1.0),
    radius=0.1,
    height=5.0,
    resolution=10,
    
)
#?pv.Cylinder 
cyl
# Out:
# PolyData (0x7fe2bbb5da08)
#   N Cells:	12
#   N Points:	40
#   X Bounds:	-9.511e-02, 9.511e-02
#   Y Bounds:	-1.000e-01, 1.000e-01
#   Z Bounds:	-2.500e+00, 2.500e+00
#   N Arrays:	2

# %%
p = pv.Plotter(shape=(1,1))

# %%
p.add_mesh(cyl, color="tan", show_edges=True)
# Out:
# (vtkRenderingOpenGL2Python.vtkOpenGLActor)0x7fe2bbb76408

# %%
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FE2BBC5C860>

# %%
pwd
# Out:
# '/home/gfa/GSDMA2019/playground'

# %%
xyz = pd.read_csv('/home/gfa/GSDMA2019/data/ground_surface.csv')

# %%
type(xyz)
# Out:
# pandas.core.frame.DataFrame

# %%
xyz_numpy = xyz.to_numpy()

# %%
cloud = pv.PolyData(xyz_numpy)
p_surface = pv.Plotter(shape=(1,1))
type(cloud)
# Out:
# pyvista.core.pointset.PolyData

# %%
#cloud.plot(point_size=15)

# %%
cyl_structured = pv.CylinderStructured(
    radius=0.5, height=10.0, center=(0.0, 0.0, 0.0), direction=(1.0, 0.0, 0.0), theta_resolution=32, z_resolution=10)

# %%
p = pv.Plotter(shape=(1,1))
pp = pv.Plotter(shape=(1,1))

# %% [markdown]
# ### Create delaunay surface

# %%
surf = cloud.delaunay_2d()
p.add_mesh(surf, color="tan", show_edges=True)
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FE2BBC5E4E0>

# %%
surf.plot(show_edges=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FE2BBC5E550>

# %%
? pv.Plotter

# %%
#p.add_mesh(cyl_structured, color="tan", show_edges=True)
#p.add_mesh(cloud, color="tan", show_edges=True)
#p.show()

# %%
#pp.add_mesh(cyl_structured, color="tan", show_edges=True)
#pp.show()

# %% [markdown]
# ## Afficher un plan
