# %% [markdown]
# # Example of using the project class

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
from striplog import Component, Decor, Legend, Interval, Position
from core.omf import Borehole3D, striplog_legend_to_omf_legend 
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from core.core import Project
from utils.orm import get_interval_list

# %% [markdown]
# ### Define the components and the way to display them

# %%
components = [Component({'lithology': 'siltstone', 'colour': 'grey'}),
              Component({'lithology': 'anhydrite'}),
              Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'}),
              Component({'lithology': 'dolomite'}),
              Component({'lithology': 'siltstone', 'colour': 'red'}),
              Component({'lithology': 'limestone'})]
list_of_decors=[]
hatches = ['=', 'x', '.', 's', '=', 'b']
colours = ['#888888', '#882222', '#AAAAAA', '#CC22CC', '#CC2222', '#2222CC']
for i in range(len(components)):
    d = {'color': colours[i],
         'hatch': hatches[i],
         'component': components[i],
         'width': 3}
    decor = Decor(d)
    list_of_decors.append(decor)
legend = Legend(list_of_decors)

# %% [markdown]
# ## Get the interval list

# %%
engine = create_engine('sqlite:///tmp/test_orm_db.db', echo=True)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# ### Create the Borehole 3D object using the legend

# %%
p = Project(session, legend=legend)
# Out:
# 2020-12-26 11:12:03,597 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-12-26 11:12:03,598 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-26 11:12:03,600 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-12-26 11:12:03,601 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-26 11:12:03,605 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-12-26 11:12:03,608 INFO sqlalchemy.engine.base.Engine SELECT "Boreholes".id AS "Boreholes_id"
# FROM "Boreholes"
# 2020-12-26 11:12:03,609 INFO sqlalchemy.engine.base.Engine ()
# 2020-12-26 11:12:03,614 INFO sqlalchemy.engine.base.Engine SELECT "Intervals".id AS "Intervals_id", "Intervals".borehole AS "Intervals_borehole", "Intervals".interval_number AS "Intervals_interval_number", "Intervals".description AS "Intervals_description", "Intervals".top_id AS "Intervals_top_id", "Intervals".base_id AS "Intervals_base_id"
# FROM "Intervals"
# WHERE ? = "Intervals".borehole
# 2020-12-26 11:12:03,615 INFO sqlalchemy.engine.base.Engine ('F01',)
# 2020-12-26 11:12:03,619 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,622 INFO sqlalchemy.engine.base.Engine (0,)
# 2020-12-26 11:12:03,626 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,629 INFO sqlalchemy.engine.base.Engine (1,)
# 2020-12-26 11:12:03,648 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,650 INFO sqlalchemy.engine.base.Engine (2,)
# 2020-12-26 11:12:03,656 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,657 INFO sqlalchemy.engine.base.Engine (3,)
# 2020-12-26 11:12:03,660 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,662 INFO sqlalchemy.engine.base.Engine (4,)
# 2020-12-26 11:12:03,668 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,681 INFO sqlalchemy.engine.base.Engine (5,)
# 2020-12-26 11:12:03,690 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,693 INFO sqlalchemy.engine.base.Engine (6,)
# 2020-12-26 11:12:03,700 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,702 INFO sqlalchemy.engine.base.Engine (7,)
# 2020-12-26 11:12:03,712 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,713 INFO sqlalchemy.engine.base.Engine (8,)
# 2020-12-26 11:12:03,716 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,722 INFO sqlalchemy.engine.base.Engine (9,)
# 2020-12-26 11:12:03,728 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,734 INFO sqlalchemy.engine.base.Engine (10,)
# 2020-12-26 11:12:03,743 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,746 INFO sqlalchemy.engine.base.Engine (11,)
# 2020-12-26 11:12:03,749 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,750 INFO sqlalchemy.engine.base.Engine (12,)
# 2020-12-26 11:12:03,752 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,759 INFO sqlalchemy.engine.base.Engine (13,)
# 2020-12-26 11:12:03,761 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,762 INFO sqlalchemy.engine.base.Engine (14,)
# 2020-12-26 11:12:03,766 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,770 INFO sqlalchemy.engine.base.Engine (15,)
# 2020-12-26 11:12:03,774 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,775 INFO sqlalchemy.engine.base.Engine (16,)
# 2020-12-26 11:12:03,782 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,783 INFO sqlalchemy.engine.base.Engine (17,)
# 2020-12-26 11:12:03,797 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,800 INFO sqlalchemy.engine.base.Engine (18,)
# 2020-12-26 11:12:03,805 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,811 INFO sqlalchemy.engine.base.Engine (19,)
# 2020-12-26 11:12:03,816 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,817 INFO sqlalchemy.engine.base.Engine (20,)
# 2020-12-26 11:12:03,821 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,827 INFO sqlalchemy.engine.base.Engine (21,)
# 2020-12-26 11:12:03,834 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,836 INFO sqlalchemy.engine.base.Engine (22,)
# 2020-12-26 11:12:03,841 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,864 INFO sqlalchemy.engine.base.Engine (23,)
# 2020-12-26 11:12:03,871 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,872 INFO sqlalchemy.engine.base.Engine (24,)
# 2020-12-26 11:12:03,877 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,878 INFO sqlalchemy.engine.base.Engine (25,)
# 2020-12-26 11:12:03,880 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,883 INFO sqlalchemy.engine.base.Engine (26,)
# 2020-12-26 11:12:03,889 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,890 INFO sqlalchemy.engine.base.Engine (27,)
# 2020-12-26 11:12:03,892 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,893 INFO sqlalchemy.engine.base.Engine (28,)
# 2020-12-26 11:12:03,895 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,897 INFO sqlalchemy.engine.base.Engine (29,)
# 2020-12-26 11:12:03,901 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,902 INFO sqlalchemy.engine.base.Engine (30,)
# 2020-12-26 11:12:03,908 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,912 INFO sqlalchemy.engine.base.Engine (31,)
# 2020-12-26 11:12:03,916 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,918 INFO sqlalchemy.engine.base.Engine (32,)
# 2020-12-26 11:12:03,923 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,927 INFO sqlalchemy.engine.base.Engine (33,)
# 2020-12-26 11:12:03,931 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,936 INFO sqlalchemy.engine.base.Engine (34,)
# 2020-12-26 11:12:03,944 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,948 INFO sqlalchemy.engine.base.Engine (35,)
# 2020-12-26 11:12:03,956 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,958 INFO sqlalchemy.engine.base.Engine (36,)
# 2020-12-26 11:12:03,962 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,967 INFO sqlalchemy.engine.base.Engine (37,)
# 2020-12-26 11:12:03,972 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:03,975 INFO sqlalchemy.engine.base.Engine (38,)
# 2020-12-26 11:12:03,983 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,000 INFO sqlalchemy.engine.base.Engine (39,)
# 2020-12-26 11:12:04,005 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,008 INFO sqlalchemy.engine.base.Engine (40,)
# 2020-12-26 11:12:04,016 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,017 INFO sqlalchemy.engine.base.Engine (41,)
# 2020-12-26 11:12:04,021 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,023 INFO sqlalchemy.engine.base.Engine (42,)
# 2020-12-26 11:12:04,030 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,033 INFO sqlalchemy.engine.base.Engine (43,)
# 2020-12-26 11:12:04,039 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,045 INFO sqlalchemy.engine.base.Engine (44,)
# 2020-12-26 11:12:04,049 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,051 INFO sqlalchemy.engine.base.Engine (45,)
# 2020-12-26 11:12:04,061 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,067 INFO sqlalchemy.engine.base.Engine (46,)
# 2020-12-26 11:12:04,074 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,079 INFO sqlalchemy.engine.base.Engine (47,)
# 2020-12-26 11:12:04,083 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,087 INFO sqlalchemy.engine.base.Engine (48,)
# 2020-12-26 11:12:04,095 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,096 INFO sqlalchemy.engine.base.Engine (49,)
# [Interval({'top': Position({'middle': 14.3, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 51.24117647058824, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 51.24117647058824, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 54.81764705882354, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 54.81764705882354, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 56.55882352941177, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 56.55882352941177, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 58.86470588235295, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 60.464705882352945, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 61.45294117647059, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 61.45294117647059, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 62.77058823529413, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 62.77058823529413, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 63.94705882352942, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Siltstone, red', 'data': {}, 'components': [Component({'lithology': 'siltstone', 'colour': 'red'})]}), Interval({'top': Position({'middle': 63.94705882352942, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 64.37058823529412, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 64.37058823529412, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 65.0764705882353, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Siltstone, grey', 'data': {}, 'components': [Component({'lithology': 'siltstone', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 65.0764705882353, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 66.77058823529413, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 66.77058823529413, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 71.10000000000001, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 71.10000000000001, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 71.80588235294118, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 71.80588235294118, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 81.78235294117647, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 81.78235294117647, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'base': Position({'middle': 85.78235294117647, 'x': 0.0, 'y': 0.0, 'units': 'm'}), 'description': 'Siltstone, grey', 'data': {}, 'components':  ...
# Borehole geometry created successfully !
# 2020-12-26 11:12:04,203 INFO sqlalchemy.engine.base.Engine SELECT "Intervals".id AS "Intervals_id", "Intervals".borehole AS "Intervals_borehole", "Intervals".interval_number AS "Intervals_interval_number", "Intervals".description AS "Intervals_description", "Intervals".top_id AS "Intervals_top_id", "Intervals".base_id AS "Intervals_base_id"
# FROM "Intervals"
# WHERE ? = "Intervals".borehole
# 2020-12-26 11:12:04,205 INFO sqlalchemy.engine.base.Engine ('F02',)
# 2020-12-26 11:12:04,208 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,212 INFO sqlalchemy.engine.base.Engine (50,)
# 2020-12-26 11:12:04,214 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,215 INFO sqlalchemy.engine.base.Engine (51,)
# 2020-12-26 11:12:04,217 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,217 INFO sqlalchemy.engine.base.Engine (52,)
# 2020-12-26 11:12:04,220 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,222 INFO sqlalchemy.engine.base.Engine (53,)
# 2020-12-26 11:12:04,224 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,226 INFO sqlalchemy.engine.base.Engine (54,)
# 2020-12-26 11:12:04,227 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,228 INFO sqlalchemy.engine.base.Engine (55,)
# 2020-12-26 11:12:04,230 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,230 INFO sqlalchemy.engine.base.Engine (56,)
# 2020-12-26 11:12:04,234 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,238 INFO sqlalchemy.engine.base.Engine (57,)
# 2020-12-26 11:12:04,241 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,243 INFO sqlalchemy.engine.base.Engine (58,)
# 2020-12-26 11:12:04,246 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,246 INFO sqlalchemy.engine.base.Engine (59,)
# 2020-12-26 11:12:04,248 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,249 INFO sqlalchemy.engine.base.Engine (60,)
# 2020-12-26 11:12:04,250 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,251 INFO sqlalchemy.engine.base.Engine (61,)
# 2020-12-26 11:12:04,255 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,256 INFO sqlalchemy.engine.base.Engine (62,)
# 2020-12-26 11:12:04,259 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,260 INFO sqlalchemy.engine.base.Engine (63,)
# 2020-12-26 11:12:04,262 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,266 INFO sqlalchemy.engine.base.Engine (64,)
# 2020-12-26 11:12:04,267 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,270 INFO sqlalchemy.engine.base.Engine (65,)
# 2020-12-26 11:12:04,274 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,277 INFO sqlalchemy.engine.base.Engine (66,)
# 2020-12-26 11:12:04,280 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,280 INFO sqlalchemy.engine.base.Engine (67,)
# 2020-12-26 11:12:04,282 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,283 INFO sqlalchemy.engine.base.Engine (68,)
# 2020-12-26 11:12:04,285 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,289 INFO sqlalchemy.engine.base.Engine (69,)
# 2020-12-26 11:12:04,293 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,294 INFO sqlalchemy.engine.base.Engine (70,)
# 2020-12-26 11:12:04,295 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,296 INFO sqlalchemy.engine.base.Engine (71,)
# 2020-12-26 11:12:04,297 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,298 INFO sqlalchemy.engine.base.Engine (72,)
# 2020-12-26 11:12:04,300 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,300 INFO sqlalchemy.engine.base.Engine (73,)
# 2020-12-26 11:12:04,305 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,306 INFO sqlalchemy.engine.base.Engine (74,)
# 2020-12-26 11:12:04,311 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,312 INFO sqlalchemy.engine.base.Engine (75,)
# 2020-12-26 11:12:04,314 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,315 INFO sqlalchemy.engine.base.Engine (76,)
# 2020-12-26 11:12:04,317 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,318 INFO sqlalchemy.engine.base.Engine (77,)
# 2020-12-26 11:12:04,322 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,323 INFO sqlalchemy.engine.base.Engine (78,)
# 2020-12-26 11:12:04,340 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,342 INFO sqlalchemy.engine.base.Engine (79,)
# 2020-12-26 11:12:04,349 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,350 INFO sqlalchemy.engine.base.Engine (80,)
# 2020-12-26 11:12:04,355 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,358 INFO sqlalchemy.engine.base.Engine (81,)
# 2020-12-26 11:12:04,363 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,367 INFO sqlalchemy.engine.base.Engine (82,)
# 2020-12-26 11:12:04,370 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,381 INFO sqlalchemy.engine.base.Engine (83,)
# 2020-12-26 11:12:04,385 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,387 INFO sqlalchemy.engine.base.Engine (84,)
# 2020-12-26 11:12:04,394 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,398 INFO sqlalchemy.engine.base.Engine (85,)
# 2020-12-26 11:12:04,410 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,414 INFO sqlalchemy.engine.base.Engine (86,)
# 2020-12-26 11:12:04,421 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,439 INFO sqlalchemy.engine.base.Engine (87,)
# 2020-12-26 11:12:04,451 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,453 INFO sqlalchemy.engine.base.Engine (88,)
# 2020-12-26 11:12:04,463 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,467 INFO sqlalchemy.engine.base.Engine (89,)
# 2020-12-26 11:12:04,476 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,481 INFO sqlalchemy.engine.base.Engine (90,)
# 2020-12-26 11:12:04,490 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,491 INFO sqlalchemy.engine.base.Engine (91,)
# 2020-12-26 11:12:04,505 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,508 INFO sqlalchemy.engine.base.Engine (92,)
# 2020-12-26 11:12:04,510 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,514 INFO sqlalchemy.engine.base.Engine (93,)
# 2020-12-26 11:12:04,522 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,523 INFO sqlalchemy.engine.base.Engine (94,)
# 2020-12-26 11:12:04,527 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,530 INFO sqlalchemy.engine.base.Engine (95,)
# 2020-12-26 11:12:04,538 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,540 INFO sqlalchemy.engine.base.Engine (96,)
# 2020-12-26 11:12:04,547 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,552 INFO sqlalchemy.engine.base.Engine (97,)
# 2020-12-26 11:12:04,557 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,560 INFO sqlalchemy.engine.base.Engine (98,)
# 2020-12-26 11:12:04,582 INFO sqlalchemy.engine.base.Engine SELECT "Positions".id AS "Positions_id", "Positions".upper AS "Positions_upper", "Positions".middle AS "Positions_middle", "Positions".lower AS "Positions_lower", "Positions".x AS "Positions_x", "Positions".y AS "Positions_y"
# FROM "Positions"
# WHERE "Positions".id = ?
# 2020-12-26 11:12:04,583 INFO sqlalchemy.engine.base.Engine (99,)
# [Interval({'top': Position({'middle': 14.3, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 51.24117647058824, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 51.24117647058824, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 54.81764705882354, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 54.81764705882354, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 56.55882352941177, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 56.55882352941177, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 58.86470588235295, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 60.464705882352945, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 61.45294117647059, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Anhydrite', 'data': {}, 'components': [Component({'lithology': 'anhydrite'})]}), Interval({'top': Position({'middle': 61.45294117647059, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 62.77058823529413, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 62.77058823529413, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 63.94705882352942, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Siltstone, red', 'data': {}, 'components': [Component({'lithology': 'siltstone', 'colour': 'red'})]}), Interval({'top': Position({'middle': 63.94705882352942, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 64.37058823529412, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 64.37058823529412, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 65.0764705882353, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Siltstone, grey', 'data': {}, 'components': [Component({'lithology': 'siltstone', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 65.0764705882353, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 66.77058823529413, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 66.77058823529413, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 71.10000000000001, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 71.10000000000001, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 71.80588235294118, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Dolomite', 'data': {}, 'components': [Component({'lithology': 'dolomite'})]}), Interval({'top': Position({'middle': 71.80588235294118, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 81.78235294117647, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'description': 'Sandstone, grey, vf-f', 'data': {}, 'components': [Component({'lithology': 'sandstone', 'grainsize': 'vf-f', 'colour': 'grey'})]}), Interval({'top': Position({'middle': 81.78235294117647, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'base': Position({'middle': 85.78235294117647, 'x': 20.0, 'y': 20.0, 'units': 'm'}), 'des ...
# Borehole geometry created successfully !

# %%
p.plot3d()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F1D211E9278>

# %%
p.plot3d(x3d=True)
# Out:
# <html>
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge"/>
# <title>X3D scene</title>
#  <p><script type='text/javascript' src='http://www.x3dom.org/download/x3dom.js'> </script>
# <link rel='stylesheet' type='text/css' href='http://www.x3dom.org/download/x3dom.css'/>
# </head>
# <body>
# <p>
#  For interaction, click in the view and press "a" to see the whole scene. For more info on interaction, please read  <a href="https://doc.x3dom.org/tutorials/animationInteraction/navigation/index.html">the docs</a>
# </p>
# <x3d width='968px' height='600px'>
#  <scene>
# <viewpoint position="-1.94639 1.79771 -2.89271" orientation="0.03886 0.99185 0.12133 3.75685"></viewpoint>
#  <Inline nameSpaceName="Borehole" mapDEFToID="true" url="project_new_project.x3d" />
# </scene>
# </x3d>
# </body>
# </html>
